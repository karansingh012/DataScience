# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [10,15,30,40,50]
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
x = ['mon','tues','wed','thurs','frid','satur']
y = [8,10,12,14,18,22]
plt.plot(x,y)
plt.title("Bakery sales this week")
plt.xlabel("Day of the week")
plt.ylabel("sales per day")
plt.grid() # for shwoing grid
plt.show()

# %%
import matplotlib.pyplot as plt
months = [1,2,3,4]
sales = [1000,1300,2000,800]
plt.plot(months,sales,color = 'skyblue',linestyle = "--",linewidth = 2, marker = 'o',label = "Sales data 2025" )
plt.title("sales analysis")
plt.xlabel("months")
plt.ylabel("sales per months")
plt.legend(loc='upper left',fontsize = 12)
plt.grid(color='gray',linestyle=':',linewidth=1)
plt.xlim(1,4)
plt.ylim(0,2000)
plt.xticks([1,2,3,4],['m1','m2','m3','m4'])
plt.show()

# %%
products = ['A','B','C','D']
sales = [1200,3000,2400,800]
plt.bar(products,sales,color="orange",label="Sales data 2025")
plt.title("products sales comparison")
plt.xlabel("products")
plt.ylabel("sales")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
region = ['East','West','South','North']
revenue = [1000,1500,1800,2300]
plt.pie(revenue,labels=region,autopct='%1.1f%%',colors=['gold','skyblue','lightgreen','red'])
plt.title("revenue contribution by region")
plt.show()

# %%
import matplotlib.pyplot as plt
scores = [53,45,23,45,89,67,33,17,98,67,56,45,54,34,43]
plt.hist(scores,bins=5,color = "purple",edgecolor='black')
plt.title("scores distribution of student")
plt.xlabel("scores range")
plt.ylabel("student")
plt.show()

# %%
import matplotlib.pyplot as plt
hours_studies = [2,3,4,5,6,7,8]
exam_scores = [50,55,60,65,70,75,85]
plt.scatter(hours_studies,exam_scores,color='green',marker='o',label="student data")

plt.xlabel('hours studies')
plt.ylabel('exam score')
plt.title("Relationship between study time exam score")
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3],[30,20,40],color='green',marker='o',label="class a")#g1
plt.scatter([1,2,3],[50,60,70],color='orange',marker='o',label="class b")#g2


plt.xlabel('hours studies')
plt.ylabel('exam score')
plt.title("Relationship between study time exam score")
plt.legend()
plt.grid()
plt.show()

# %%
## Create a pie chart using matplotlib to represent the following data:
# Languages Popularity
# Python 30
# Java 25
# C++ 20
# JavaScript 15
# Ruby 10
import matplotlib.pyplot as plt
languages = ['Python','Java','C++','JavaScript','Ruby']
popularity = [30,25,20,15,10]
plt.pie(popularity,labels=languages,autopct='%1.1f%%',colors=['gold','skyblue','lightgreen','red','purple'])
plt.title("Languages Popularity")
plt.show()




## pie

# %%
import matplotlib.pyplot as plt 
languages = ["Hindi","English","marathi","avdhi","dehati"]
region = [30,40,10,10,10]

plt.pie(region,labels=languages, autopct='%1.1f%%',colors=["Pink","Red","yellow","green","magenta"])
plt.title("LAnguage spoken in specific region")
plt.show()

# %%
# Explain the why loops are needed and the types of loops in python.
# Discuss break and continue with example.

## for 10 marks 
# Loops are essential in programming as they allow us to execute a block of code multiple 
# times without having to write the same code repeatedly. This is particularly 
# useful when dealing with repetitive tasks, such as iterating over a collection 
# of items, performing calculations, or processing data. Loops help in reducing code 
# redundancy, improving readability, and making programs more efficient. There are two 
# primary types of loops in Python: for loops and while loops. 


# 1. For Loops: Used to iterate over a sequence (like a list, tuple, or string) 
# or other iterable objects. The syntax is straightforward and is often used when
#  the number of iterations is known beforehand.
# Example:
for i in range(5):
    print(i)

# 2. While Loops: Used to execute a block of code as long as a specified condition is true. This type of loop is useful when the number of iterations is not predetermined.
# Example:
count = 0           
while count < 5:
    print(count)
    count += 1

# Break and Continue Statements:    
# - Break Statement: Used to exit a loop prematurely when a certain condition is met. It stops the loop entirely and transfers control to the statement immediately following the loop.
# Example:
for i in range(10):
    if i == 5:
        break  # Exit the loop when i is 5
    print(i)    

# - Continue Statement: Used to skip the current iteration of a loop and move to the next iteration. It does not terminate the loop but skips the remaining code inside the loop for the current iteration.
# Example:
for i in range(10):
    if i % 2 == 0:
        continue  # Skip even numbers
    print(i)  # This will print only odd numbers

# In summary, loops are vital for automating repetitive tasks in programming, and Python provides flexible loop constructs along with control statements like break and continue to manage loop execution effectively.
#!/usr/bin/env python3
# file: read_example.py
with open('example.txt','r') as file:
    content = file.read()
    print(content)

# %%
# Write a function to find the longest word in a given list of words.
# Example: longest_word([‘apple’, ‘banana’, ‘cherry’]) returns ‘banana’.

def longest_word(words):
    if not words:
        return None  # Return None if the list is empty
    
    
    longest = words[0] # means initialize longest with the first word
    for word in words:
        if len(word) > len(longest):
            longest = word
    return longest




# Example usage:
words_list = ['apple', 'banana', 'cherry']
result = longest_word(words_list)
print("The longest word is:", result)  # Output: The longest word is: banana
# Out:
# The longest word is: banana

# %%
lst = [1,2,3,4,5,6,7,8,9]

# M = lst[0:8:2]
# m = min(M) ## min 
# print(M)
num = lst[-1::-1]
print(num)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
import math

def perfect_square(number):
    if number < 0:
        return -1
    
    root = int(math.sqrt(number))
    if root * root == number:
        return number
    return -1


perfect_square(5)  # returns 16
# Out:
# -1

# %%
import math
