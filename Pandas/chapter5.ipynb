# %% [markdown]
# # Removing.py

# %%
# df.drop(columns = ["Column Name"],inplace=True)
#print(df)
#for multiple column ko hatane ke liye sth me column ka nam likhna hai 
#like df.drop(columns = ["Column Name","Second column name"],inplace=True)

import pandas as pd 
data = {
    "Name": ['Ram', 'Shyam', 'Ghanshyam', 'Dhanshyam','Aditi','Jagdish', 'Raj', 'Simran'],
    "Age": [28,34,22,30, 29,40,25,32],
    "Salary": [50000,60000,45000,52000,49000, 70000,48000,58000],
    "Performance_Score": [85,90,78,92, 88,95,80,89]
}
df = pd.DataFrame(data)
print(df)
#After removing perforamnce score 
df.drop(columns=["Performance_Score"],inplace=True)
print(df)
# Out:
#         Name  Age  Salary  Performance_Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
#         Name  Age  Salary
# 0        Ram   28   50000
# 1      Shyam   34   60000
# 2  Ghanshyam   22   45000
# 3  Dhanshyam   30   52000
# 4      Aditi   29   49000
# 5    Jagdish   40   70000
# 6        Raj   25   48000
# 7     Simran   32   58000
