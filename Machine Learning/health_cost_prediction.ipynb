# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/karansingh/Desktop/Data Science/Machine Learning/sample_submission.csv")
print(df)
# Out:
#        id  charges
# 0    1107      0.0
# 1    1322      0.0
# 2    2314      0.0
# 3    2275      0.0
# 4    1433      0.0
# ..    ...      ...
# 550   931      0.0
# 551  2611      0.0
# 552  1701      0.0
# 553   101      0.0
# 554   316      0.0
#
# [555 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       555 non-null    int64
#  1   charges  555 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 8.8 KB

# %%
df.shape
# Out:
# (555, 2)

# %%
df.head(10)
# Out:
#      id  charges
# 0  1107      0.0
# 1  1322      0.0
# 2  2314      0.0
# 3  2275      0.0
# 4  1433      0.0
# 5  2241      0.0
# 6   966      0.0
# 7  2627      0.0
# 8  2135      0.0
# 9  2297      0.0

# %%
df.tail()
# Out:
#        id  charges
# 550   931      0.0
# 551  2611      0.0
# 552  1701      0.0
# 553   101      0.0
# 554   316      0.0

# %%
df.isnull().sum()
# Out:
# id         0
# charges    0
# dtype: int64

# %%
df.describe()
# Out:
#                 id  charges
# count   555.000000    555.0
# mean   1370.196396      0.0
# std     802.614120      0.0
# min      30.000000      0.0
# 25%     677.500000      0.0
# 50%    1360.000000      0.0
# 75%    2070.000000      0.0
# max    2768.000000      0.0

# %%
import matplotlib.pyplot as plt
## Sactter plot 
plt.scatter(df['id'],df['charges'])
plt.title("Scatter plot id vs charges")
plt.xlabel("id")
plt.ylabel("charges")
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import
