# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("/Users/karansingh/Desktop/Data Science/Machine Learning/zomato.csv",encoding="latin1")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['Restaurant Name'].value_counts()
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: count, Length: 7446, dtype: int64

# %%
df['Restaurant Name'].isnull().sum()
# Out:
# np.int64(0)

# %%
restorent_data = df['Restaurant Name'].value_counts().head(10)
plt.figure(figsize=(10,6))
plt.bar(restorent_data.index,restorent_data.values,color="orange",edgecolor="black")
plt.title("comparison between restorent and number of restorent")
plt.xlabel("restorent")
plt.ylabel("count")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df['Country Code'].value_counts()
# Out:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
df['Country Code'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['City'].value_counts()
# Out:
# City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: count, Length: 141, dtype: int64

# %%
df['City'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df[['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
       'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
       'Average Cost for two', 'Currency', 'Has Table booking',
       'Has Online delivery', 'Is delivering now', 'Switch to order menu',
       'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
       'Votes']].isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
df['Locality'].value_counts()
# Out:
# Locality
# Connaught Place                                122
# Rajouri Garden                                  99
# Shahdara                                        87
# Defence Colony                                  86
# Malviya Nagar                                   85
#                                               ...
# Lemon Tree Premier, Sector 29                    1
# Omaxe Celebration Mall, Sohna Road, Gurgaon      1
# Park Inn, Sector 15, Gurgaon                     1
# Plaza Mall, MG Road                              1
# Moda                                             1
# Name: count, Length: 1208, dtype: int64

# %%
df['Currency'].value_counts()
# Out:
# Currency
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(£)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: count, dtype: int64

# %%
city_plot = df['City'].value_counts().head(10)
plt.figure(figsize=(10,6))
plt.bar(city_plot.index,city_plot.values,color='green',edgecolor='black')
plt.title("City-wise Restaurant Count (Top 10 Cities)")
plt.xlabel("city")
plt.ylabel("count")
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

## top 10 Locality count
Locality_plot = df['Locality'].value_counts().head(10)
plt.figure(figsize=(10,6))
plt.bar(Locality_plot.index,city_plot.values,color='pink',edgecolor='black')
plt.title("Top 10 Localities With the Highest Number of Restaurants")
plt.xlabel("Locality")
plt.ylabel("count")
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

## top 10 Currency
Currency_plot = df['Currency'].value_counts().head(10)
plt.figure(figsize=(10,6))
plt.bar(Currency_plot.index,city_plot.values,color='red',edgecolor='black')
plt.title("Top 10 currency used in city")
plt.xlabel("Currency")
plt.ylabel("count")
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# /var/folders/bf/c5g8t8hs08j4x62fvvx5j4100000gn/T/ipykernel_83885/1087845766.py:29: UserWarning: Glyph 140 (\x8c) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/karansingh/Library/Python/3.14/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 140 (\x8c) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['Address'].value_counts()
# Out:
# Address
# Dilli Haat, INA, New Delhi                                                               11
# Sector 41, Noida                                                                         11
# Greater Kailash (GK) 1, New Delhi                                                        10
# The Imperial, Janpath, New Delhi                                                          9
# Cyber Hub, DLF Cyber City, Gurgaon                                                        8
#                                                                                          ..
# 23-24, Defence Colony Market, Defence Colony, New Delhi                                   1
# 28, Main Market, Defence Colony, New Delhi                                                1
# Daryaganj, New Delhi                                                                      1
# Ground Floor, E-23, Netaji Subhash Marg, Opposite Golcha Cinema, Daryaganj, New Delhi     1
# ...

# %%
df['Address'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df['Locality']
# Out:
# 0        Century City Mall, Poblacion, Makati City
# 1       Little Tokyo, Legaspi Village, Makati City
# 2       Edsa Shangri-La, Ortigas, Mandaluyong City
# 3           SM Megamall, Ortigas, Mandaluyong City
# 4           SM Megamall, Ortigas, Mandaluyong City
#                            ...
# 9546                                      Karakí_y
# 9547                                     Koôuyolu
# 9548                                   Kuruí_eôme
# 9549                                   Kuruí_eôme
# 9550                                          Moda
# Name: Locality, Length: 9551, dtype: object

# %%
df['Locality'].value_counts()
# Out:
# Locality
# Connaught Place                                122
# Rajouri Garden                                  99
# Shahdara                                        87
# Defence Colony                                  86
# Malviya Nagar                                   85
#                                               ...
# Lemon Tree Premier, Sector 29                    1
# Omaxe Celebration Mall, Sohna Road, Gurgaon      1
# Park Inn, Sector 15, Gurgaon                     1
# Plaza Mall, MG Road                              1
# Moda                                             1
# Name: count, Length: 1208, dtype: int64

# %%
df['Locality'].isnull().sum()
# Out:
# np.int64(0)

# %%
Locality_plot = df['Locality'].value_counts().head(10)
plt.figure(figsize=(10,6))
plt.bar(Locality_plot.index,Locality_plot.values,color="red",edgecolor="black")
plt.title("Compresion b/w number of restorent in one city")
plt.xlabel("city")
plt.ylabel("count")
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df['Locality Verbose'].value_counts()
# Out:
# Locality Verbose
# Connaught Place, New Delhi                    122
# Rajouri Garden, New Delhi                      99
# Shahdara, New Delhi                            87
# Defence Colony, New Delhi                      86
# Pitampura, New Delhi                           85
#                                              ...
# Ramada Gurgaon Central, Sector 44, Gurgaon      1
# Sector 5, Gurgaon                               1
# Sector 53, Gurgaon                              1
# The Claremont, MG Road, Gurgaon                 1
# Moda, ÛÁstanbul                                 1
# Name: count, Length: 1265, dtype: int64

# %%
df['Locality Verbose'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Longitude'].unique()
# Out:
# array([121.027535  , 121.014101  , 121.056831  , ...,  29.03464001,
#         29.036019  ,  29.02601603], shape=(8120,))

# %%
# df['Longitude'].value_counts()
# df.columns

# %%
# df.head()

# %%
# df[['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes']].isnull().sum()

# %%
# df_label = df_label.copy()
# df_label['Has Table booking'] = df_label['Has Table booking'].map({'Yes':1, 'No':0})
# df_label['Has Online delivery'] = df_label['Has Online delivery'].map({'Yes':1, 'No':0})
# df_label['Is delivering now'] = df_label['Is delivering now'].map({'Yes':1, 'No':0})
# df_label['Switch to order menu'] = df_label['Switch to order menu'].map({'Yes':1, 'No':0})
# df_label

# Agar tum sirf ye 10 bana do, EDA FINAL ho jata hai ✔
# 	1.	Rating Distribution
# 	2.	Votes Distribution
# 	3.	Average Cost Distribution
# 	4.	Boxplot of Cost
# 	5.	Top 10 Cities
# 	6.	Top 10 Localities
# 	7.	Price Range Distribution
# 	8.	Price Range vs Rating
# 	9.	Votes vs Rating Scatter
# 	10.	Correlation Heatmap

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df_label = df.copy()

# Step 1: encode these 3 only
le = LabelEncoder()
cols = ['City', 'Locality', 'Locality Verbose']
for col in cols:
    df_label[col] = le.fit_transform(df_label[col])

# Step 2: binary conversion - lower + strip to avoid mismatch
binary_cols = ['Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu']

for col in binary_cols:
    df_label[col] = df_label[col].astype(str).str.strip().str.lower()
    df_label[col] = df_label[col].map({'yes':1, 'no':0})
df_label
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       1 df_label = df.copy()
#       3 # Step 1: encode these 3 only
# ----> 4 le = LabelEncoder()
#       5 cols = ['City', 'Locality', 'Locality Verbose']
#       6 for col in cols:
#
# NameError: name 'LabelEncoder' is not defined

# %%
df_label = df_label.drop(['Restaurant Name','Address'],axis = 1)

# %%
df_label
# Out:
#       Restaurant ID  Country Code  City  Locality  Locality Verbose  \
# 0           6317637           162    73       171               172
# 1           6304287           162    73       593               601
# 2           6300002           162    75       308               314
# 3           6318506           162    75       862               875
# 4           6314302           162    75       862               875
# ...             ...           ...   ...       ...               ...
# 9546        5915730           208   140       517               523
# 9547        5908749           208   140       552               558
# 9548        5915807           208   140       554               561
# 9549        5916112           208   140       554               561
# 9550        5927402           208   140       670               681
#
#        Longitude   Latitude                          Cuisines  \
# 0     121.027535  14.565443        French, Japanese, Desserts
# ...

# %%
df_label = df_label.drop(['Cuisines','Currency'],axis=1)
df_label
# Out:
#       Restaurant ID  Country Code  City  Locality  Locality Verbose  \
# 0           6317637           162    73       171               172
# 1           6304287           162    73       593               601
# 2           6300002           162    75       308               314
# 3           6318506           162    75       862               875
# 4           6314302           162    75       862               875
# ...             ...           ...   ...       ...               ...
# 9546        5915730           208   140       517               523
# 9547        5908749           208   140       552               558
# 9548        5915807           208   140       554               561
# 9549        5916112           208   140       554               561
# 9550        5927402           208   140       670               681
#
#        Longitude   Latitude  Average Cost for two  Has Table booking  \
# 0     121.027535  14.565443                  1100                  1
# ...

# %%
df_label['Rating color'].value_counts()
# Out:
# Rating color
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: count, dtype: int64

# %%
df_label['Rating text'].value_counts()
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
cols = ['Rating color', 'Rating text']
for col in cols:
    df_label[col] = le.fit_transform(df_label[col])
df_label
# Out:
#       Restaurant ID  Country Code  City  Locality  Locality Verbose  \
# 0           6317637           162    73       171               172
# 1           6304287           162    73       593               601
# 2           6300002           162    75       308               314
# 3           6318506           162    75       862               875
# 4           6314302           162    75       862               875
# ...             ...           ...   ...       ...               ...
# 9546        5915730           208   140       517               523
# 9547        5908749           208   140       552               558
# 9548        5915807           208   140       554               561
# 9549        5916112           208   140       554               561
# 9550        5927402           208   140       670               681
#
#        Longitude   Latitude  Average Cost for two  Has Table booking  \
# 0     121.027535  14.565443                  1100                  1
# ...

# %%
df_label.describe()
# Out:
#        Restaurant ID  Country Code         City     Locality  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    78.301434   658.128468
# std     8.791521e+06     56.750546    23.198915   315.866515
# min     5.300000e+01      1.000000     0.000000     0.000000
# 25%     3.019625e+05      1.000000    76.000000   381.000000
# 50%     6.004089e+06      1.000000    88.000000   696.000000
# 75%     1.835229e+07      1.000000    88.000000   921.000000
# max     1.850065e+07    216.000000   140.000000  1207.000000
#
#        Locality Verbose    Longitude     Latitude  Average Cost for two  \
# count       9551.000000  9551.000000  9551.000000           9551.000000
# mean         677.304994    64.126574    25.854381           1199.210763
# std          331.727449    41.467058    11.007935          16121.183073
# min            0.000000  -157.948486   -41.330428              0.000000
# ...

# %%
# Agar tum sirf ye 10 bana do, EDA FINAL ho jata hai ✔
# 	1.	Rating Distribution
# 	2.	Votes Distribution
# 	3.	Average Cost Distribution
# 	4.	Boxplot of Cost
# 	5.	Top 10 Cities
# 	6.	Top 10 Localities
# 	7.	Price Range Distribution
# 	8.	Price Range vs Rating
# 	9.	Votes vs Rating Scatter
# 	10.	Correlation Heatmap

# Ye industry standard EDA package hai.  mujhe itna graph bana hai 

df_label
# Out:
#       Restaurant ID  Country Code  City  Locality  Locality Verbose  \
# 0           6317637           162    73       171               172
# 1           6304287           162    73       593               601
# 2           6300002           162    75       308               314
# 3           6318506           162    75       862               875
# 4           6314302           162    75       862               875
# ...             ...           ...   ...       ...               ...
# 9546        5915730           208   140       517               523
# 9547        5908749           208   140       552               558
# 9548        5915807           208   140       554               561
# 9549        5916112           208   140       554               561
# 9550        5927402           208   140       670               681
#
#        Longitude   Latitude  Average Cost for two  Has Table booking  \
# 0     121.027535  14.565443                  1100                  1
# ...

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Out:
# (9551, 21)
