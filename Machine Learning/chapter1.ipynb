# %% [markdown]
# # AI/Ml

# %%
# Out:
# Standard Scaller Output:
#    Study_Hours  Test_Scores
# 0    -1.414214    -1.414214
# 1    -0.707107    -0.707107
# 2     0.000000     0.000000
# 3     0.707107     0.707107
# 4     1.414214     1.414214
