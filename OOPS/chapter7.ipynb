# %% [markdown]
# # Custom exception(Raise and throw an exception)

# %%
class Error(Exception):
    pass
class dobException(Error):
    pass

# %%
year = int(input("Enter your year"))
age = 2024-year
try:
    if age>=20 and age<=30:
        print("You are eligible for vote")
    else:
        raise dobException
except dobException:
    print("Sorry your age is should we greater than 20 and less than 30")
# Out:
# Sorry your age is should we greater than 20 and less than 30
