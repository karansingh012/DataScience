# %% [markdown]
# # Magic method in python
# magic method in python is also known as dunder methods(double underscore method) that start and end with double underscores. These enable you to define the behavior of object for built in operations, uch as arithmetic operations, comparisons, and more

# %% [markdown]
# # Magic method
# Magic method are predefined methods in python hat you can override to change the behavior of your objects. Some common magic methods include.
# * init: initializes a new instance of a class.
# * str: Returns a string representation of an object.
# * repr: returns an official string representation of an object.
# * len: return the length of an object.
# * getitem: gets a item from a container.
# * setitem: sets a item in a container.

# %%
# __init__: initializes a new instance of a class. 
# __str__: Returns a string representation of an object. 
# __repr__: returns an official string representation of an object.
# __len__: return the length of an object.
# __getitem__: gets a item from a container.
# __setitem__: sets a item in a container.

# %%
class person:
    pass

person = person()
print(person)

# %%
#3 basic method 
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def __str__(self):
        return f"{self.name}.{self.age} years old"
    def __repr__(self):
        return f"person(name = {self.name},age={self.age})"

Person = person("Karan",20)
print(Person)
print(repr(Person))
# Out:
# Karan.20 years old
# person(name = Karan,age=20)

# %% [markdown]
# # operator overloading in python

# %%
## mathematical operation for vector 





## create object from the vector
# Out:
# zsh: string expected after -c
