# %%
import os 
cwd = os.getcwd()
print(f'Current working directory is {cwd}')
# Out:
# Current working directory is /Users/karansingh/Desktop/Data Science/importent topics

# %%
# create a new directory 
import os

# create a new directory 
import os

new_directory = "package"
os.makedirs(new_directory, exist_ok=True)

print(f"Directory '{new_directory}' create")
# Out:
# Directory 'package' create

# %%
# listing file and directories 
items = os.listdir(".")
print(items)
# Out:
# ['fileoperation.ipynb', 'destination.txt', 'example.csv', 'source.text', 'package.ipynb', 'sqlite.ipynb', 'functions.ipynb', 'wrokwithfilepath.ipynb', 'test_dir', 'example.bin', 'example.txt', 'standardlibrary.ipynb', 'test.db', 'destination.text', 'package']

# %%
# joining the pasth 
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder/file.txt

# %%
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# /Users/karansingh/Desktop/Data Science/importent topics /folder/file.txt

# %%
path = "example1.txt"
if os.path.exists(path):
    print(f"the path '{path}' exists")
else:
    print(f"the path '{path}'does not exists")
# Out:
# the path 'example1.txt'does not exists

# %%
## 2nd method to check the file is persent or not 
path = "example1.txt"
if os.path.isfile(path):
    print(f"the path '{path}' exists in file")
elif os.path.isdir(path):
    print(f"the path '{path}' exists in directory")
else:
    print(f"the path '{path}'does not exists")
# Out:
# the path 'example1.txt'does not exists

# %%
# getting the absoulte path 
relative_path = 'example.txt'
absoulte_path = os.path.abspath(relative_path)
print(absoulte_path)
# Out:
# /Users/karansingh/Desktop/Data Science/importent topics /example.txt
