# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package.subpackage.mult import multiply
multiply(3,2)
# Out:
# 6

# %%
## to import multiple condition 
from package.maths import*
addition(5,6)
subtarction(8,5)
# Out:
# 3
