# %%
import array 
arr = array.array("i",[1,2,3,4,5])
print(arr)
## import math
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
# random 
import random 
print(random.randint(1,3))
print(random.choice(['apple','banana','cherry']))
# Out:
# 3
# cherry

# %%
# file and directory access 
import os 
print(os.getcwd())
# Out:
# /Users/karansingh/Desktop/Data Science/importent topics

# %%
os.mkdir('test_dir')

# %%
# high level operration on file and collection of files
import shutil
shutil.copyfile('source.text','destination.text')
# Out:
# 'destination.text'

# %%
# Data serialization 
import json
data = {'name':'karan','age':20}
json_star = json.dumps(data)
print(json_star)
print(type(json_star))

parsed_data = json.loads(json_star)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "karan", "age": 20}
# <class 'str'>
# {'name': 'karan', 'age': 20}
# <class 'dict'>

# %%
import csv 
with open('example.csv',mode = 'w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age','department'])
    writer.writerow(['karan',19,'Data Science'])
with open('example.csv',mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age', 'department']
# ['karan', '19', 'Data Science']

# %%
from datetime import datetime,timedelta
now = datetime.now()
print(now)
# Out:
# 2025-11-26 11:13:57.581793

# %%
from datetime import datetime,timedelta
now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2025-11-26 11:15:30.288759
# 2025-11-25 11:15:30.288759

# %%
#time 
import time 
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1764136083.881417
# 1764136085.886682
