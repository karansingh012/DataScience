# %%
with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# how r u
# karan is my name

# %%
with open('example.txt','r') as file:
    for line in file:
        # print(line)
        print(line.strip()) # this strip() function is remove new line character
# Out:
# how r u
# karan is my name
