# %% [markdown]
# # Python Logging
# Logging is crucial aspect of any application, providing a way to track events, errors, and operational information. python's built-in logging module offers a flexible framework for emitting log message from python programs. In this lesson, we will cover the basic of logging, including how to configure logging, log levels, and best practices for using in python applications.

# %%
import logging
## configure basic logging setting
logging.basicConfig(level=logging.DEBUG)


## log message with different severity levels 
logging.debug("This is a debug message")
logging.info("This is a info message")
logging.warning("This is a warning message")
logging.error("This is a error message")
logging.critical("This is critical message")
# Out:
# DEBUG:root:This is a debug message
# INFO:root:This is a info message
# WARNING:root:This is a warning message
# ERROR:root:This is a error message
# CRITICAL:root:This is critical message

# %% [markdown]
# # 🔥 Logging Levels (from lowest to highest severity)
#
# 1. DEBUG
# 	*	Use: Developer-level details
# 	*	Contains: Internal info, variable values, flow of the program
# 	*	Example: User object created: {id: 2, name: "Karan"}
#
# ⸻
#
# 2. INFO
# 	*	Use: General updates
# 	*	Contains: Normal operations
# 	*	Example: Server started on port 5000
#
# ⸻
#
# 3. WARNING
# 	*	Use: Something unexpected happened
# 	*	Contains: Non-breaking issues
# 	*	Example: Low disk space
#
# ⸻
#
# 4. ERROR
# 	*	Use: Something failed
# 	*	Contains: Recoverable errors
# 	*	Example: Database connection failed. Retrying...
#
# ⸻
#
# 5. CRITICAL (or FATAL)
# 	*	Use: Severe errors that stop the program
# 	*	Contains: System crash-level issues
# 	*	Example: System crashed: out of memory
#
# ⸻

# %%
import logging
logging.basicConfig(
    filename='app.log',
    filemode='w',
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)
## log message with different severity levels 
logging.debug("This is a debug message")
logging.info("This is a info message")
logging.warning("This is a warning message")
logging.error("This is a error message")
logging.critical("This is critical message")
# Out:
# DEBUG:root:This is a debug message
# INFO:root:This is a info message
# WARNING:root:This is a warning message
# ERROR:root:This is a error message
# CRITICAL:root:This is critical message
